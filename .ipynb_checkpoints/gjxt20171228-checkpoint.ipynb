# %%
#高校基础数据分析系统
#学生成绩分析
#前缀：gjfx
#开发：peuland
#时间：2017-12-28
print ('高校基础数据分析系统-gjfx')
# Out:
# 高校基础数据分析系统-gjfx

# %%
#准备学生成绩原始数据
#在教务系统中编写查询学生成绩的视图moly_view_cjb
print ('准备学生成绩原始数据')
# Out:
# 准备学生成绩原始数据

# %%
#测试显示学生成绩
#处理列表list数据
print ('测试显示学生成绩-列表数据')
# Out:
# 测试显示学生成绩-列表数据

# %%
#测试显示学生成绩
#处理外部文本数据-#学生成绩-测试.csv
print ('测试显示学生成绩-处理外部文本数据')

#代码实现方式一
try:
    #file_name='data/rede.txt'
    #file_name='data/student_cj.csv' 
    file_name='data/学生成绩-测试.csv'   #可以使用中文文件名
 
    #UnicodeDecodeError: 'gbk' codec can't decode byte 0xaf in position 384: illegal multibyte sequence    
    #file_data=open (file_name)  
    file_data=open(file_name,'r',encoding='utf-8')  #encoding='utf-8'必须加上，否则处理中文（utf-8编码）会出错
 
    row_data=file_data.readline()
    print (row_data)
    
    for row_data in file_data :
        record=row_data.split(',')
        #print (row_data,record)
        index=record[0]
        xn=record[1]
        xq=record[2]
        kch=record[3]
        xh=record[5]
        cj=record[7]
        print (index,xn,xq,kch,xh,cj)    

except IOError as err:
    print('File error.'+str(err))
finally:
    file_data.close()
# Out:
# 测试显示学生成绩-处理外部文本数据
# ﻿XH,XNM,XQM,KCH_ID,JXB_ID,XH_ID,CJ,BFZCJ,JD,CJXZM,KCXZ,XF,KCXZDM
#
# 1 2014 12 A0010019 050214215 60
# 2 2014 12 A1550025 050214215 87
# 3 2014 12 A0550002 050214215 86
# 4 2014 12 A0010032 050214215 85
# 5 2014 12 30100002 050214215 93
# 6 2014 12 T1000816 050214215 75
# 7 2014 12 A0010004 050214215 65
# 8 2014 12 A0010019 050214215 48
# 9 2014 12 05300273 050214215 63
# 10 2014 12 G0310031 050214215 68
# 11 2014 12 A0550011 050214215 75
# 12 2014 12 A001008a 050214215 79
# 13 2014 12 05300252 050214215 48
# 14 2014 12 03500151 050214215 83
# 15 2014 12 A0010030 050214215 79
# 16 2014 12 05300068 050214215 85
# 17 2014 12 A0520052 050214215 85
# 18 2014 12 05300252 050214215 60
# 19 2014 3 30300003 050214215 63
# 20 2014 3 A001007a 050214215 75
# 21 2014 3 T1000815 050214215 72
# 22 2014 3 A0010018 050214215 60
# 23 2014 3 09100101 050214215 64
# 24 2014 3 28300001 050214215 77
# 25 2014 3 03500155 050214215 69
# 26 2014 3 A0010003 050214215 62
# 27 2015 12 A0550014 050214215 80
# 28 2015 12 A0520034 050214215 34
# 29 2015 12 G0110020 050214215 89
# 30 2015 12 A0010006 050214215 63
# 31 2015 12 A0010025 050214215 61
# 32 2015 12 05300261 050214215 61
# 33 2015 12 05300070 050214215 84
# 34 2015 12 T1000818 050214215 78
# 35 2015 12 A0550006 050214215 79
# 36 2015 12 05300250 050214215 80
# 37 2015 3 A0010005 050214215 61
# 38 2015 3 A0010024 050214215 60
# 39 2015 3 05300069 050214215 81
# 40 2015 3 05300275 050214215 64
# 41 2015 3 A001009a 050214215 80
# 42 2015 3 G0210026 050214215 33
# 43 2015 3 T1000817 050214215 75
# 44 2015 3 A0010031 050214215 82
# 45 2015 3 A0010037 050214215 90
# 46 2016 12 05300089 050214215 66
# 47 2016 12 05300022 050214215 94
# 48 2016 12 05300057 050214215 79
# 49 2016 12 05300260 050214215 62
# 50 2016 12 A0530023 050214215 65
# 51 2016 12 A0520034 050214215 61
# 52 2016 12 G4000030 050214215 74
# 53 2016 12 05300256 050214215 78
# 54 2016 12 10100006 050214215 100
# 55 2016 12 08100001 050214215 82
# 56 2016 12 A0520056 050214215 65
# 57 2016 12 A0530058 050214215 67
# 58 2016 12 A0530002 050214215 70
# 59 2016 3 A0520001 050214215 77
# 60 2016 3 10100005 050214215 92
# 61 2016 3 G0610038 050214215 62
# 62 2016 3 A0520051 050214215 30
# 63 2016 3 A0520034 050214215 0
# 64 2016 3 A0550001 050214215 84
# 65 2016 3 05300257 050214215 89
# 66 2016 3 G4000023 050214215 60
# 67 2016 3 A0540011 050214215 86
# 68 2016 3 05300040 050214215 62
# 69 2016 3 A0520051 050214215 22

# %%
#测试显示学生成绩
#处理外部Excle格式数据-#学生成绩-测试.xls

# %%
#测试显示学生成绩
#处理本机数据库数据（MYSQL）
print ('测试显示学生成绩-处理本机数据库数据（MYSQL）')
# Out:
# 测试显示学生成绩-处理本机数据库数据（MYSQL）

# %%
#测试显示学生成绩
#学生成绩图表显示
#coding=utf-8
from matplotlib.font_manager import FontProperties 
import matplotlib.pyplot as plt
print ('测试显示学生成绩-学生成绩图表显示')

font = FontProperties(fname=r"C:\\WINDOWS\\Fonts\\simsun.ttc", size=14)  #C:\WINDOWS\Fonts  

try:
    file_name='data/学生成绩-测试.csv'   #可以使用中文文件名 
    file_data=open(file_name,'r',encoding='utf-8')  #encoding='utf-8'必须加上，否则处理中文（utf-8编码）会出错
    row_data=file_data.readline()  #读出表头，以免影响后面的实际数据处理
    print (row_data)
    
    xx,yy=[],[]
    for row_data in file_data :
        record=row_data.split(',')
        #print (row_data,record)
        index=record[0]
        xn=record[1]
        xq=record[2]
        kch=record[3]
        xh=record[5]
        cj=record[7]
        #print (index,xn,xq,kch,xh,cj)    
        xx.append(float(index))
        yy.append(float(cj))
        
    #print(xx,'\n',yy)
    plt.grid()
    plt.plot(xx,yy)
    #plt.title('单个学生成绩分析')
    plt.title("单个学生成绩分析",fontproperties=font)
    plt.xlabel('课程门次',fontproperties=font)
    plt.ylabel('课程成绩',fontproperties=font)
    plt.show()
except IOError as err:
    print('File error.'+str(err))
finally:
    file_data.close()
# Out:
# 测试显示学生成绩-学生成绩图表显示
# ﻿XH,XNM,XQM,KCH_ID,JXB_ID,XH_ID,CJ,BFZCJ,JD,CJXZM,KCXZ,XF,KCXZDM

# %%
#测试显示学生成绩
#处理远程数据库数据（MYSQL）
print ('测试显示学生成绩-处理远程数据库数据（MYSQL）')
# Out:
# 测试显示学生成绩-处理远程数据库数据（MYSQL）

# %%
#测试显示学生成绩
#处理本机数据库数据（Oracle）
print ('测试显示学生成绩-处理本机数据库数据（Oracle）')
# Out:
# 测试显示学生成绩-处理本机数据库数据（Oracle）

# %%
#测试显示学生成绩
#处理远程数据库数据（Oracle）
from __future__ import print_function
import cx_Oracle
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties 

print ('测试显示学生成绩-处理远程数据库数据（Oracle）')

font = FontProperties(fname=r"C:\\WINDOWS\\Fonts\\simsun.ttc", size=14)  #C:\WINDOWS\Fonts  
# Connect as user "hr" with password "welcome" to the "oraclepdb" service running on this computer.
connection = cx_Oracle.connect("gjfx","caca070706","10.28.200.188/orcl")
cursor = connection.cursor()
SQL="select xh_id,bfzcj from zftal_jwlg.gjfx_view_cjb where jxb_id='16-2017-2)-A0930058-200500027-2'"
cursor.execute(SQL)

xh_set,cj_set=[],[]
for record_data in cursor:
    xh=record_data[0]
    cj=record_data[1]

    xh_set.append(xh)
    cj_set.append(cj)
   
plt.grid()
plt.plot(xh_set,cj_set)

plt.title("单门课程学生成绩分析",fontproperties=font)
plt.xlabel('学生学号',fontproperties=font)
plt.ylabel('课程成绩',fontproperties=font)
plt.show()
# Out:
# 测试显示学生成绩-处理远程数据库数据（Oracle）

# %%
#from matplotlib.pyplot import *
import matplotlib.pyplot as plt

plt.plot([0, 1], [0, 1])      # plot a line from (0, 0) to (1, 1)
plt.title("a strait line")
plt.xlabel("x value")
plt.ylabel("y value")
plt.show()
#savefig("demo.jpg")

points=[[0,0],[1,1],[1,2],[2,2],[3,4]]
#plt.plot([0, 1], [0, 1])      # plot a line from (0, 0) to (1, 1)
plt.plot(points)
plt.title("a strait line")
plt.xlabel("x value")
plt.ylabel("y value")
plt.show()

# %%
import matplotlib.pyplot as plt

X, Y = [], []
for line in open('data/mydata.txt', 'r'):
    values = [float(s) for s in line.split()]
    X.append(values[0])
    Y.append(values[1])

plt.plot(X, Y)
plt.show()

# %%
#web应用程序Demo测试代码
print ('web应用程序Demo测试代码')
# Out:
# web应用程序Demo测试代码
