# %%
#高校基础数据分析系统
#学生成绩分析
#前缀：gjfx
#开发：peuland
#时间：2017-12-28
print ('高校基础数据分析系统-gjfx')
# Out:
# 高校基础数据分析系统-gjfx

# %%
#准备学生成绩原始数据
#在教务系统中编写查询学生成绩的视图moly_view_cjb
print ('准备学生成绩原始数据')
# Out:
# 准备学生成绩原始数据

# %%
#测试显示学生成绩
#处理列表list数据
print ('测试显示学生成绩-列表数据')
# Out:
# 测试显示学生成绩-列表数据

# %%
#测试显示学生成绩
#处理外部文本数据-#学生成绩-测试.csv
print ('测试显示学生成绩-处理外部文本数据')

#代码实现方式一
try:
    #file_name='data/rede.txt'
    #file_name='data/student_score.txt' 
    file_name='../data/学生成绩-测试.csv'   #可以使用中文文件名
 
    #UnicodeDecodeError: 'gbk' codec can't decode byte 0xaf in position 384: illegal multibyte sequence    
    #file_data=open (file_name)  
    file_data=open(file_name,'r',encoding='utf-8')  #encoding='utf-8'必须加上，否则处理中文（utf-8编码）会出错
 
    row_data=file_data.readline()
    print (row_data)
    
    for row_data in file_data :
        record=row_data.split(',')
        #print (row_data,record)
        index=record[0]
        xn=record[1]
        xq=record[2]
        kch=record[3]
        xh=record[5]
        cj=record[7]
        #print (index,xn,xq,kch,xh,cj)    

except IOError as err:
    print('File error.'+str(err))
finally:
    file_data.close()
# Out:
# 测试显示学生成绩-处理外部文本数据
# ﻿XH,XNM,XQM,KCH_ID,JXB_ID,XH_ID,CJ,BFZCJ,JD,CJXZM,KCXZ,XF,KCXZDM

# %%
#测试显示学生成绩
#处理外部Excle格式数据-#学生成绩-测试.xls

# %%
#测试显示学生成绩
#处理本机数据库数据（MYSQL）
print ('测试显示学生成绩-处理本机数据库数据（MYSQL）')
# Out:
# 测试显示学生成绩-处理本机数据库数据（MYSQL）

# %%
#★★★★★测试显示学生成绩
#学生成绩图表显示
#coding=utf-8
from matplotlib.font_manager import FontProperties 
import matplotlib.pyplot as plt
print ('测试显示学生成绩-学生成绩图表显示')

plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
fig=plt.figure(figsize=[10,8])

try:
    file_name='../data/学生成绩-测试.csv'   #可以使用中文文件名 
    file_data=open(file_name,'r',encoding='utf-8')  #encoding='utf-8'必须加上，否则处理中文（utf-8编码）会出错
    row_data=file_data.readline()  #读出表头，以免影响后面的实际数据处理
    print (row_data)
    
    xx,yy=[],[]
    for row_data in file_data :
        record=row_data.split(',')
        #print (row_data,record)
        index=record[0]
        xn=record[1]
        xq=record[2]
        kch=record[3]
        xh=record[5]
        cj=record[7]
        #print (index,xn,xq,kch,xh,cj)    
        xx.append(float(index))
        yy.append(float(cj))
        
    #print(xx,'\n',yy)
    
    plt.grid()
    #plt.plot(xx,yy)
    plt.scatter(xx,yy)
    plt.plot([-1,len(xx)+2],[60,60],'r-.')
    
    #plt.title('单个学生成绩分析')
    plt.title("单个学生成绩分析")
    plt.xlabel('课程门次')
    plt.ylabel('课程成绩')
    plt.show()
    plt.close()
except IOError as err:
    print('File error.'+str(err))
finally:
    file_data.close()
# Out:
# 测试显示学生成绩-学生成绩图表显示
# ﻿XH,XNM,XQM,KCH_ID,JXB_ID,XH_ID,CJ,BFZCJ,JD,CJXZM,KCXZ,XF,KCXZDM

# %%
#★★★★★测试显示指定单个学生成绩/显示课程编号
#学生成绩图表显示
#coding=utf-8
from matplotlib.font_manager import FontProperties 
import matplotlib.pyplot as plt
#print ('测试显示学生成绩-学生成绩图表显示')

plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
fig=plt.figure(figsize=[30,8])

try:
    file_name='../data/学生成绩-测试.csv'   #可以使用中文文件名 
    file_data=open(file_name,'r',encoding='utf-8')  #encoding='utf-8'必须加上，否则处理中文（utf-8编码）会出错
    row_data=file_data.readline()  #读出表头，以免影响后面的实际数据处理
    #print (row_data)
    
    xx,yy,kch=[],[],[]
    for row_data in file_data :
        record=row_data.split(',')
        #print (row_data,record)
        index=record[0]
        #xn=record[1]
        #xq=record[2]
        kh=record[3]
        #xh=record[5]
        cj=record[7]
        #print (index,xn,xq,kch,xh,cj)    
        xx.append(index)
        yy.append(float(cj))
        kch.append(kh)
        
    #print(xx,'\n',yy)
    ax1=fig.add_subplot(111)
    ax1.grid()
    ax1.scatter(kch,yy)
    ax1.plot([-1,len(xx)+2],[60,60],'r-.')
    
    ax1.set_title("单个学生成绩分析")
    ax1.set_xlabel('课程编号')
    ax1.set_ylabel('课程成绩')
    plt.xticks(range(len(kch)),kch,rotation=75)
    
    plt.show()
    #plt.savefig('../img/grcjfx01.png')   #保存为图片
except IOError as err:
    print('File error.'+str(err))
finally:
    file_data.close()

# %%
#测试显示学生成绩
#处理远程数据库数据（MYSQL）
print ('测试显示学生成绩-处理远程数据库数据（MYSQL）')
# Out:
# 测试显示学生成绩-处理远程数据库数据（MYSQL）

# %%
#测试显示指定单个学生成绩/显示课程编号
#学生成绩图表显示
#处理本机数据库数据（Oracle）
print ('测试显示学生成绩-处理本机数据库数据（Oracle）')
# Out:
# 测试显示学生成绩-处理本机数据库数据（Oracle）

# %%
#★★★★★测试显示指定单个学生成绩/显示课程编号
#学生成绩图表显示
#处理远程数据库数据（Oracle）
import cx_Oracle
import matplotlib.pyplot as plt

print ('测试显示指定单个学生成绩（Oracle）')
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签

connection = cx_Oracle.connect("gjfx","caca070706","10.28.200.188/orcl")
cursor = connection.cursor()
xh='072614209'
SQL="select kch_id,bfzcj from zftal_jwlg.gjfx_view_cjb where xh='"+xh+"' order by xnmmc,xqmmc,kch_id"
cursor.execute(SQL)

kch_set,cj_set=[],[]
for record_data in cursor:
    kch=record_data[0]
    cj=record_data[1]

    kch_set.append(kch)
    cj_set.append(cj)
   
plt.figure(figsize=[15,8])
plt.grid()
plt.scatter(kch_set,cj_set)
plt.plot([-1,len(kch_set)+2],[60,60],'r-.')

plt.title("单个学生成绩分析")
plt.xlabel('课程代码')
plt.ylabel('课程成绩')
plt.xticks(range(len(kch_set)),kch_set,rotation=85)

plt.show()
#plt.savefig('../img/dmkccj01.png')
# Out:
# 测试显示指定单个学生成绩（Oracle）
# select kch_id,bfzcj from zftal_jwlg.gjfx_view_cjb where xh='072614209' order by xnmmc,xqmmc,kch_id

# %%
#★★★★★测试显示课程单个教学班成绩/(2016-2017-2)-A0930058-200500027-2
#处理远程数据库数据（Oracle）
import cx_Oracle
import matplotlib.pyplot as plt

#print ('测试显示学生成绩-处理远程数据库数据（Oracle）')
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
connection = cx_Oracle.connect("gjfx","caca070706","10.28.200.188/orcl")
cursor = connection.cursor()
jxb_id='13-2014-2)-A0390007-200000025-1'
SQL="select xh,bfzcj from zftal_jwlg.gjfx_view_cjb where jxb_id='"+jxb_id+"' order by xh"
cursor.execute(SQL)

xh_set,cj_set=[],[]
for record_data in cursor:
    xh=record_data[0]
    cj=record_data[1]

    xh_set.append(xh)
    cj_set.append(cj)
   
plt.figure(figsize=[15,8])
plt.grid()
#plt.plot(xh_set,cj_set)
plt.scatter(xh_set,cj_set)
plt.plot([-1,len(xh_set)+2],[60,60],'r-.')

plt.title("课程单个教学班成绩分析")
plt.xlabel('学生学号')
plt.ylabel('课程成绩')
plt.xticks(range(len(xh_set)),xh_set,rotation=85)

plt.show()
#plt.savefig('../img/dmkccj01.png')

# %%
#★★★★★测试显示课程单个教学班成绩/(2016-2017-2)-A0930058-200500027-2
#处理远程数据库数据（Oracle）
import cx_Oracle
import matplotlib.pyplot as plt

#print ('测试显示学生成绩-处理远程数据库数据（Oracle）')

plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
connection = cx_Oracle.connect("gjfx","caca070706","10.28.200.188/orcl")
cursor = connection.cursor()
SQL="select xh,bfzcj from zftal_jwlg.gjfx_view_cjb where jxbmc='(2016-2017-2)-A0930058-200500027-2' order by xh"
cursor.execute(SQL)

cj_set,cj_set1=[],[]
for record_data in cursor:
    cj=record_data[1]
    if (cj>=60):
        cj_set.append(cj)
    else:
        cj_set1.append(cj)

xx=range(len(cj_set))
xx1=range(len(cj_set1))

plt.grid()
plt.scatter(xx,cj_set,color='b',marker='^')
plt.scatter(xx1,cj_set1,color='r',marker='x')

plt.title("单门课程学生成绩分析")
plt.xlabel('序号')
plt.ylabel('课程成绩')

plt.show()
# Out:
# 测试显示学生成绩-处理远程数据库数据（Oracle）

# %%
#★★★★★测试显示课程单门成绩/高等数学
#处理远程数据库数据（Oracle）
import cx_Oracle
import matplotlib.pyplot as plt

#print ('测试显示课程单门成绩/高等数学A（1）-处理远程数据库数据（Oracle）')
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签

connection = cx_Oracle.connect("gjfx","caca070706","10.28.200.188/orcl")
cursor = connection.cursor()
#SQL="select xh,bfzcj,xnmmc,xqmmc,jg_id,njmc,zyh_id,jsxm,jxbmc,kch_id from zftal_jwlg.gjfx_view_cjb where kcmc='高等数学A（1）' order by jg_id,zyh_id,njmc,xnmmc,xqmmc,xh"
#kcmc='高等数学A（1）'
kcmc='高等数学B（1）'
#kcmc='大学英语（2）'
#kcmc='马克思主义基本原理概论'
SQL="select bfzcj,count(*) cnt  from zftal_jwlg.gjfx_view_cjb where kcmc like '%"+kcmc+"%' group by bfzcj order by bfzcj"
cursor.execute(SQL)

cj_set,cnt_set=[],[]
for record_data in cursor:
    cj=record_data[0]
    cnt=record_data[1]
    
    cnt_set.append(cnt)
    cj_set.append(cj)
   
plt.figure(figsize=[15,8])
plt.grid()
#plt.plot(xh_set,cj_set)
plt.scatter(cj_set,cnt_set)
plt.plot([60,60],[-2,250],'r-.')

plt.title("课程全部学生成绩分析")
plt.xlabel('课程成绩')
plt.ylabel('学生人数')
#plt.xticks(range(len(cj_set)),xh_set,rotation=85)

plt.show()
#plt.savefig('../img/dmkccj01.png')

# %%
#★★★★★测试显示课程单门成绩/高等数学
#处理远程数据库数据（Oracle）
import cx_Oracle
import matplotlib.pyplot as plt

#print ('测试显示课程单门成绩/高等数学A（1）-处理远程数据库数据（Oracle）')
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签

connection = cx_Oracle.connect("gjfx","caca070706","10.28.200.188/orcl")
cursor = connection.cursor()
#SQL="select xh,bfzcj,xnmmc,xqmmc,jg_id,njmc,zyh_id,jsxm,jxbmc,kch_id from zftal_jwlg.gjfx_view_cjb where kcmc='高等数学A（1）' order by jg_id,zyh_id,njmc,xnmmc,xqmmc,xh"
kcmc='高等数学A（1）'
SQL="select jg_id,bfzcj,count(*) cnt  from zftal_jwlg.gjfx_view_cjb where kcmc='"+kcmc+"' group by jg_id,bfzcj order by jg_id,bfzcj"
cursor.execute(SQL)

jg_set,cj_set,cnt_set=[],[],[]
for record_data in cursor:
    jg=record_data[0]
    cj=record_data[1]
    cnt=record_data[2]*20
    
    jg_set.append(jg)
    cnt_set.append(cnt)
    cj_set.append(cj)
   
plt.figure(figsize=[15,8])
plt.grid()
#plt.plot(xh_set,cj_set)
plt.scatter(jg_set,cj_set,s=cnt_set)
plt.plot([0,17],[60,60],'r-.')

plt.title("课程全部学生成绩分析")
plt.xlabel('部门代码')
plt.ylabel('课程成绩')

plt.show()
#plt.savefig('../img/dmkccj01.png')

# %%
#★★★★★测试显示课程单门成绩/大学英语
#处理远程数据库数据（Oracle）
import cx_Oracle
import matplotlib.pyplot as plt

#print ('测试显示课程单门成绩/高等数学A（1）-处理远程数据库数据（Oracle）')
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签

connection = cx_Oracle.connect("gjfx","caca070706","10.28.200.188/orcl")
cursor = connection.cursor()
SQL="select jg_id,bfzcj,count(*) cnt  from zftal_jwlg.gjfx_view_cjb where  kcmc like '大学英语%' group by jg_id,bfzcj order by jg_id,bfzcj"
#SQL="select jg_id,bfzcj,count(*) cnt  from zftal_jwlg.gjfx_view_cjb where  kcmc like '%六级%' \
#group by jg_id,bfzcj order by jg_id,bfzcj"
#思想道德修养与法律基础/教师书写技能
cursor.execute(SQL)

jg_set,cj_set,cnt_set=[],[],[]
for record_data in cursor:
    jg=record_data[0]
    cj=record_data[1]
    cnt=record_data[2]*18
    
    jg_set.append(jg)
    cnt_set.append(cnt)
    cj_set.append(cj)
   
plt.figure(figsize=[15,8])
plt.grid()
#plt.plot(xh_set,cj_set)
plt.scatter(jg_set,cj_set,s=cnt_set)
plt.plot([0,17],[60,60],'r-.')

plt.title("课程全部学生成绩分析（大学英语）")
#plt.title("课程全部学生成绩分析（英语六级）")
plt.xlabel('部门代码')
plt.ylabel('课程成绩')

plt.show()
plt.savefig('../img/大学英语01.png')

# %%
#★★★★★专业课程成绩分布分析
#处理远程数据库数据（Oracle）
import cx_Oracle
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签

connection = cx_Oracle.connect("gjfx","caca070706","10.28.200.188/orcl")
cursor = connection.cursor()

SQL="select zyh_id,zyh,zymc,jg_id from zftal_jwlg.zftal_xtgl_zydmb"
cursor.execute(SQL)

zhy_id_set,zyh_set,zymc_set,jg_id_set=[],[],[],[]

for record_data in cursor:
    zhy_id=record_data[0]
    zyh=record_data[1]
    zymc=record_data[2]
    jg_id=record_data[3]
    
    zhy_id_set.append(zhy_id)
    zyh_set.append(zyh)
    zymc_set.append(zymc)
    jg_id_set.append(jg_id)

#print(zhy_id_set,zyh_set,zymc_set,jg_id_set)

# %%
#★★★★★整体专业课程成绩分布分析
#处理远程数据库数据（Oracle）
import cx_Oracle
import matplotlib.pyplot as plt

#print ('测试显示课程单门成绩/高等数学A（1）-处理远程数据库数据（Oracle）')
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签

connection = cx_Oracle.connect("gjfx","caca070706","10.28.200.188/orcl")
cursor = connection.cursor()
#zyh_id='0926'  #物联网
#zyh_id='0121'  #0121	秘书学
zyh_id='Z052'      #Z052	光电信息科学与工程
point_size=18
SQL="select kcmc,bfzcj,count(*) cnt from zftal_jwlg.gjfx_view_cjb where zyh_id='"+zyh_id+"' group by kcmc,bfzcj order by kcmc,bfzcj"
cursor.execute(SQL)

kcmc_set,cj_set,cnt_set=[],[],[]
for record_data in cursor:
    kcmc=record_data[0]
    cj=record_data[1]
    cnt=record_data[2]*point_size
    
    kcmc_set.append(kcmc)
    cnt_set.append(cnt)
    cj_set.append(cj)
   
plt.figure(figsize=[100,18])
plt.grid()
plt.xticks(rotation=90)
plt.scatter(kcmc_set,cj_set,s=cnt_set)
plt.plot([kcmc_set[0],kcmc_set[len(kcmc_set)-1]],[60,60],'r-.')

plt.title(zyh_id+"专业全部课程成绩分析")
plt.xlabel('课程名称')
plt.ylabel('课程成绩')

plt.savefig('../img/按专业成绩分布/zycj'+zyh_id+'-1.png')
plt.show()

# %%
#★★★★★整体专业课程成绩分布分析，执行时间很长，按课程名称排序
#处理远程数据库数据（Oracle）
import cx_Oracle
import matplotlib.pyplot as plt

#print ('测试显示课程单门成绩/高等数学A（1）-处理远程数据库数据（Oracle）')
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签

connection = cx_Oracle.connect("gjfx","caca070706","10.28.200.188/orcl")
cursor = connection.cursor()

#SQL="select zyh_id,zyh,zymc,jg_id from zftal_jwlg.zftal_xtgl_zydmb"
SQL="select zyh_id,zyh,zymc,jg_id from zftal_jwlg.zftal_xtgl_zydmb "+ \
    "where zyh_id in (select zyh_id from zftal_jwlg.gjfx_view_cjb group by zyh_id)"
cursor.execute(SQL)

zyh_id_set,zyh_set,zymc_set,jg_id_set=[],[],[],[]
point_size=18
    
for record_data in cursor:
    zyh_id=record_data[0]
    zyh=record_data[1]
    zymc=record_data[2]
    jg_id=record_data[3]

    zyh_id_set.append(zyh_id)
    zyh_set.append(zyh)
    zymc_set.append(zymc)
    jg_id_set.append(jg_id)

for ii in range(len(zyh_id_set)):
#for ii in range(3):
    zyh_id=zyh_id_set[ii]
    SQL1="select kcmc,bfzcj,count(*) cnt from zftal_jwlg.gjfx_view_cjb where zyh_id='"+zyh_id+"' group by kcmc,bfzcj order by kcmc,bfzcj"
    print(SQL1)
    cursor.execute(SQL1)
    
    kcmc_set,cj_set,cnt_set=[],[],[]
    for record_data in cursor:
        kcmc=record_data[0]
        cj=record_data[1]
        cnt=record_data[2]*point_size

        kcmc_set.append(kcmc)
        cnt_set.append(cnt)
        cj_set.append(cj)

    plt.figure(figsize=[100,18])
    plt.grid()
    plt.xticks(rotation=90) 
    plt.scatter(kcmc_set,cj_set,s=cnt_set)
    plt.plot([kcmc_set[0],kcmc_set[len(kcmc_set)-1]],[60,60],'r-.')

    plt.title(zyh_set[ii]+zymc_set[ii]+"专业全部课程成绩分析")
    plt.xlabel('课程名称')
    plt.ylabel('课程成绩')

    plt.savefig('../img/按专业成绩分布/zycj'+zyh_set[ii]+zymc_set[ii]+'-1.png')
    plt.close()
       
#plt.show()
print("ok")
# Out:
# select kcmc,bfzcj,count(*) cnt from zftal_jwlg.gjfx_view_cjb where zyh_id='Y011' group by kcmc,bfzcj order by kcmc,bfzcj
# select kcmc,bfzcj,count(*) cnt from zftal_jwlg.gjfx_view_cjb where zyh_id='Y021' group by kcmc,bfzcj order by kcmc,bfzcj
# select kcmc,bfzcj,count(*) cnt from zftal_jwlg.gjfx_view_cjb where zyh_id='Y022' group by kcmc,bfzcj order by kcmc,bfzcj
# select kcmc,bfzcj,count(*) cnt from zftal_jwlg.gjfx_view_cjb where zyh_id='Y041' group by kcmc,bfzcj order by kcmc,bfzcj
# select kcmc,bfzcj,count(*) cnt from zftal_jwlg.gjfx_view_cjb where zyh_id='Y042' group by kcmc,bfzcj order by kcmc,bfzcj
# select kcmc,bfzcj,count(*) cnt from zftal_jwlg.gjfx_view_cjb where zyh_id='Y051' group by kcmc,bfzcj order by kcmc,bfzcj
# select kcmc,bfzcj,count(*) cnt from zftal_jwlg.gjfx_view_cjb where zyh_id='Y061' group by kcmc,bfzcj order by kcmc,bfzcj
# select kcmc,bfzcj,count(*) cnt from zftal_jwlg.gjfx_view_cjb where zyh_id='Y081' group by kcmc,bfzcj order by kcmc,bfzcj
# ...

# %%
#★★★★★某年级专业课程成绩分布分析
#处理远程数据库数据（Oracle）
import cx_Oracle
import matplotlib.pyplot as plt

#print ('测试显示课程单门成绩/高等数学A（1）-处理远程数据库数据（Oracle）')
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签

connection = cx_Oracle.connect("gjfx","caca070706","10.28.200.188/orcl")
cursor = connection.cursor()
#zyh_id='0926'  #物联网
#zyh_id='0121'  #0121	秘书学
zyh_id='Z052'      #Z052	光电信息科学与工程
point_size=18
#SQL="select kcmc,bfzcj,count(*) cnt from zftal_jwlg.gjfx_view_cjb where zyh_id='"+zyh_id+"' group by kcmc,bfzcj order by kcmc,bfzcj"
SQL="select jg_id,zyh_id,njmc,xnmmc,xqmmc,kcmc,bfzcj,count(*) cnt from zftal_jwlg.gjfx_view_cjb where jg_id='12' \
    group by jg_id,zyh_id,njmc,xnmmc,xqmmc,kcmc,bfzcj having count(*)>10  order by xnmmc,xqmmc,kcmc,bfzcj"
cursor.execute(SQL)
print(SQL)

kcmc_set,cj_set,cnt_set=[],[],[]
for record_data in cursor:
    kcmc=record_data[5]
    cj=record_data[1]
    cnt=record_data[2]*point_size
    
    kcmc_set.append(kcmc)
    cnt_set.append(cnt)
    cj_set.append(cj)

print(cnt_set,cj_set)    
#'''    
plt.figure(figsize=[100,18])
plt.grid()
plt.xticks(rotation=90)
plt.scatter(kcmc_set,cj_set,s=cnt_set)
plt.plot([kcmc_set[0],kcmc_set[len(kcmc_set)-1]],[60,60],'r-.')

plt.title(zyh_id+"专业全部课程成绩分析")
plt.xlabel('课程名称')
plt.ylabel('课程成绩')

plt.savefig('../img/按年级专业成绩分布/zycj'+zyh_id+'-1.png')
plt.show()
#'''
# Out:
# select jg_id,zyh_id,njmc,xnmmc,xqmmc,kcmc,bfzcj,count(*) cnt from zftal_jwlg.gjfx_view_cjb where jg_id='12'     group by jg_id,zyh_id,njmc,xnmmc,xqmmc,kcmc,bfzcj having count(*)>10  order by xnmmc,xqmmc,kcmc,bfzcj
# ...

# %%
#★★★★★单个教师课程成绩分布分析
#处理远程数据库数据（Oracle）
import cx_Oracle
import matplotlib.pyplot as plt

#print ('测试显示课程单门成绩/高等数学A（1）-处理远程数据库数据（Oracle）')
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签

connection = cx_Oracle.connect("gjfx","caca070706","10.28.200.188/orcl")
cursor = connection.cursor()
jsxm='秦志刚'      #沈健/秦志刚/赵根林/高燕/宋东兴/陈希棠/邹永林/周思林/张根华/徐惠钢/殷旭东
point_size=30
#SQL="select kcmc,bfzcj,count(*) cnt from zftal_jwlg.gjfx_view_cjb where jsxm='"+jsxm+"' group by kcmc,bfzcj order by kcmc,bfzcj"
SQL="select kcmc,bfzcj,count(*) cnt from zftal_jwlg.gjfx_xscjb where jsxm='"+jsxm+"' group by kcmc,bfzcj order by kcmc,bfzcj"
cursor.execute(SQL)

kcmc_set,cj_set,cnt_set=[],[],[]
for record_data in cursor:
    kcmc=record_data[0]
    cj=record_data[1]
    cnt=record_data[2]*point_size
    
    kcmc_set.append(kcmc)
    cnt_set.append(cnt)
    cj_set.append(cj)

kcmc_enum=list(set(kcmc_set))
len1=len(kcmc_enum)
#print (kcmc_enum)
#print (len(kcmc_enum))
#print (kcmc_enum)

plt.figure(figsize=[2*len1,13])
plt.grid()
plt.xticks(rotation=30)
plt.yticks(range(0,101,5))
plt.scatter(kcmc_set,cj_set,s=cnt_set)
plt.plot([-1,len1],[60,60],'r-.')


plt.title("单个教师全部课程成绩分析")
plt.xlabel('课程名称')
plt.ylabel('课程成绩')

pic_file_name='../img/'+jsxm+'任课成绩分析.png'
plt.savefig(pic_file_name)
plt.show()
# Out:
# ['程序设计基础（VB）', '微机组装与维护', '美术概论']
# 3

# %%
#★★★★★开课学院所有教师个人课程成绩分布分析（）
#处理远程数据库数据（Oracle）
import cx_Oracle
import matplotlib.pyplot as plt
import os

#print ('测试显示课程单门成绩/高等数学A（1）-处理远程数据库数据（Oracle）')
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签

connection = cx_Oracle.connect("gjfx","caca070706","10.28.200.188/orcl")
cursor = connection.cursor()
point_size=30

#人文学院/经济与管理学院/外国语学院/数学与统计学院/物理与电子工程学院/生物与食品工程学院/机械工程学院
#马克思主义学院/计算机科学与工程学院/体育部/汽车工程学院/电气与自动化工程学院/化学与材料工程学院/艺术与服装工程学院
#党委学生工作部、学生工作处/党委保卫部、保卫处、人民武装部
kkxy='党委保卫部、保卫处、人民武装部'
path_name='../img/'+kkxy
isExists=os.path.exists(path_name)
if not isExists:
    os.mkdir(path_name)

SQL1="select jsxm  from zftal_jwlg.gjfx_view_jxrwb where kkxy='"+kkxy+"' group by jsxm order by jsxm"
cursor.execute(SQL1)
result1=cursor.fetchall()
if result1:
    for record_data1 in result1:
        jsxm=record_data1[0]
        if not jsxm:
            jsxm=''
        SQL2="select kcmc,bfzcj,count(*) cnt from zftal_jwlg.gjfx_xscjb where jsxm='"+jsxm+"' group by kcmc,bfzcj order by kcmc,bfzcj"
        cursor.execute(SQL2)
        result2=cursor.fetchall()
        if result2:
            kcmc_set,cj_set,cnt_set=[],[],[]            
            for record_data2 in result2:
                kcmc=record_data2[0]
                cj=record_data2[1]
                cnt=record_data2[2]*point_size

                kcmc_set.append(kcmc)
                cnt_set.append(cnt)
                cj_set.append(cj)

            kcmc_enum=list(set(kcmc_set))
            len1=len(kcmc_enum)

            plt.figure(figsize=[2*len1,13])
            plt.scatter(kcmc_set,cj_set,s=cnt_set)
            plt.plot([-1,len1],[60,60],'r-.')
            plt.grid()
            plt.xticks(rotation=30)
            plt.yticks(range(0,101,5))
            plt.title("单个教师全部课程成绩分析")
            plt.xlabel('课程名称')
            plt.ylabel('课程成绩')

            pic_file_name='../img/'+kkxy+'/'+jsxm+'任课成绩分析.png'
            print (pic_file_name)
            plt.savefig(pic_file_name)
            plt.close()
# Out:
# d:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# ../img/党委保卫部、保卫处、人民武装部/白小斌任课成绩分析.png
# ../img/党委保卫部、保卫处、人民武装部/曹文雯任课成绩分析.png
# ../img/党委保卫部、保卫处、人民武装部/陈清森任课成绩分析.png
# ../img/党委保卫部、保卫处、人民武装部/陈燕红任课成绩分析.png
# ../img/党委保卫部、保卫处、人民武装部/陈友洋任课成绩分析.png
# ../img/党委保卫部、保卫处、人民武装部/戴明新任课成绩分析.png
# ../img/党委保卫部、保卫处、人民武装部/方玉任课成绩分析.png
# ../img/党委保卫部、保卫处、人民武装部/高英杰任课成绩分析.png
# ../img/党委保卫部、保卫处、人民武装部/耿发展任课成绩分析.png
# ../img/党委保卫部、保卫处、人民武装部/顾国梅任课成绩分析.png
# ../img/党委保卫部、保卫处、人民武装部/顾元华任课成绩分析.png
# ../img/党委保卫部、保卫处、人民武装部/何龙山任课成绩分析.png
# ../img/党委保卫部、保卫处、人民武装部/合春红任课成绩分析.png
# ../img/党委保卫部、保卫处、人民武装部/胡荣春任课成绩分析.png
# ../img/党委保卫部、保卫处、人民武装部/蒋超任课成绩分析.png
# ../img/党委保卫部、保卫处、人民武装部/李亚任课成绩分析.png
# ...

# %%
#★★★★★各部门所属教师个人课程成绩分布分析
#处理远程数据库数据（Oracle）
import cx_Oracle
import matplotlib.pyplot as plt
import os

#print ('测试显示课程单门成绩/高等数学A（1）-处理远程数据库数据（Oracle）')
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签

connection = cx_Oracle.connect("gjfx","caca070706","10.28.200.188/orcl")
cursor = connection.cursor()
point_size=30

SQL0="select jgdm,jgmc from zftal_jwlg.zftal_xtgl_jgdmb order by jgdm"
cursor.execute(SQL0)
result0=cursor.fetchall()
for reco in result0:
    jgdm=reco[0]
    jgmc=reco[1]
    path_name='../img/'+jgmc
    isExists=os.path.exists(path_name)
    if not isExists:
        os.mkdir(path_name)

    SQL1="select xm from zftal_jwlg.jw_jg_jzgjbxxb where jg_id='"+jgdm+"' order by xm"
    cursor.execute(SQL1)
    result1=cursor.fetchall()
    if result1:
        for record_data1 in result1:
            jsxm=record_data1[0]
            if not jsxm:
                jsxm=''
            SQL2="select kcmc,bfzcj,count(*) cnt from zftal_jwlg.gjfx_xscjb where jsxm='"+jsxm+"' group by kcmc,bfzcj order by kcmc,bfzcj"
            cursor.execute(SQL2)
            result2=cursor.fetchall()
            if result2:
                kcmc_set,cj_set,cnt_set=[],[],[]            
                for record_data2 in result2:
                    kcmc=record_data2[0]
                    cj=record_data2[1]
                    cnt=record_data2[2]*point_size

                    kcmc_set.append(kcmc)
                    cnt_set.append(cnt)
                    cj_set.append(cj)

                kcmc_enum=list(set(kcmc_set))
                len1=len(kcmc_enum)

                plt.figure(figsize=[2*len1,13])
                plt.scatter(kcmc_set,cj_set,s=cnt_set)
                plt.plot([-1,len1],[60,60],'r-.')
                plt.grid()
                plt.xticks(rotation=30)
                plt.yticks(range(0,101,5))
                plt.title("单个教师全部课程成绩分析")
                plt.xlabel('课程名称')
                plt.ylabel('课程成绩')

                pic_file_name=path_name+'/'+jsxm+'任课成绩分析.png'
                print (pic_file_name)
                plt.savefig(pic_file_name)
                plt.close()
# Out:
# d:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# ../img/人文学院/包中华任课成绩分析.png
# ../img/人文学院/曹逸梅任课成绩分析.png
# ../img/人文学院/陈丹任课成绩分析.png
# ../img/人文学院/陈清森任课成绩分析.png
# ../img/人文学院/陈亚天任课成绩分析.png
# ../img/人文学院/陈雯任课成绩分析.png
# ../img/人文学院/戴维娜任课成绩分析.png
# ../img/人文学院/待定教师1任课成绩分析.png
# ../img/人文学院/待定教师10任课成绩分析.png
# ../img/人文学院/待定教师2任课成绩分析.png
# ../img/人文学院/待定教师3任课成绩分析.png
# ../img/人文学院/待定教师4任课成绩分析.png
# ../img/人文学院/待定教师5任课成绩分析.png
# ../img/人文学院/待定教师6任课成绩分析.png
# ../img/人文学院/待定教师7任课成绩分析.png
# ../img/人文学院/待定教师8任课成绩分析.png
# ../img/人文学院/待定教师9任课成绩分析.png
# ../img/人文学院/邓根芹任课成绩分析.png
# ../img/人文学院/丁卫萍任课成绩分析.png
# ../img/人文学院/费振新任课成绩分析.png
# ../img/人文学院/甘滢任课成绩分析.png
# ...

# %%
#单个教师课程成绩分布分析（杀手排行榜，不及格率）
#处理远程数据库数据（Oracle）

# %%
#web应用程序Demo测试代码
print ('web应用程序Demo测试代码')
# Out:
# web应用程序Demo测试代码
