# %%
"""
--ver 0.1
--饼图表示
--（应届）在籍性别人数/性别比例/各年级(2014级以后)
select xbm,njdm_id,count(*) from JW_XJGL_XSJBXXB where xjztdm='01' and njdm_id>='2014' group by xbm,njdm_id order by njdm_id,xbm
   	XBM	NJDM_ID	COUNT(*)
1	1	2014	2204
2	2	2014	1936
3	1	2015	2079
4	2	2015	2158
5	1	2016	2456
6	2	2016	2772
7	1	2017	2740
8	2	2017	2824
"""
import matplotlib.pyplot as plt

init_data=((1,1,2014,2204),
           (2,2,2014,1936),
           (3,1,2015,2079),
           (4,2,2015,2158),
           (5,1,2016,2456),
           (6,2,2016,2772),
           (7,1,2017,2740),
           (8,2,2017,2824))

#print (init_data)
#print (init_data[0][3]+init_data[1][3])
sum_2014=init_data[0][3]+init_data[1][3]    #2014
sum_2015=init_data[2][3]+init_data[3][3]    #2015
sum_2016=init_data[4][3]+init_data[5][3]    #2016
sum_2017=init_data[6][3]+init_data[7][3]    #2017
mfrate_2014=[init_data[0][3]/sum_2014,init_data[1][3]/sum_2014]
mfrate_2015=[init_data[2][3]/sum_2015,init_data[3][3]/sum_2015]
mfrate_2016=[init_data[4][3]/sum_2016,init_data[5][3]/sum_2016]
mfrate_2017=[init_data[6][3]/sum_2017,init_data[7][3]/sum_2017]
#print (sum_data)


labels='male','female'
colors='yellowgreen','gold'
explode=0,0.1

plt.figure(figsize=(15, 6))
plt.subplot(1,4,1)
plt.axis('equal')
#plt.title('sfs')
plt.pie(mfrate_2014,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True,startangle=30)

plt.subplot(1,4,2)
plt.axis('equal')
plt.pie(mfrate_2015,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True,startangle=30)

plt.subplot(1,4,3)
plt.axis('equal')
plt.pie(mfrate_2016,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True,startangle=30)

plt.subplot(1,4,4)
plt.axis('equal')
plt.pie(mfrate_2017,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True,startangle=30)

plt.show()

# %%
"""
--ver 0.2/显示年级标签
--饼图表示
--（应届）在籍性别人数/性别比例/各年级(2014级以后)
select xbm,njdm_id,count(*) from JW_XJGL_XSJBXXB where xjztdm='01' and njdm_id>='2014' group by xbm,njdm_id order by njdm_id,xbm
--XBM	NJDM_ID	COUNT(*)
"""
import matplotlib.pyplot as plt

init_data=((1,1,2014,2204),
           (2,2,2014,1936),
           (3,1,2015,2079),
           (4,2,2015,2158),
           (5,1,2016,2456),
           (6,2,2016,2772),
           (7,1,2017,2740),
           (8,2,2017,2824))

sum_2014=init_data[0][3]+init_data[1][3]    #2014
sum_2015=init_data[2][3]+init_data[3][3]    #2015
sum_2016=init_data[4][3]+init_data[5][3]    #2016
sum_2017=init_data[6][3]+init_data[7][3]    #2017
mfrate_2014=[init_data[0][3]/sum_2014,init_data[1][3]/sum_2014]
mfrate_2015=[init_data[2][3]/sum_2015,init_data[3][3]/sum_2015]
mfrate_2016=[init_data[4][3]/sum_2016,init_data[5][3]/sum_2016]
mfrate_2017=[init_data[6][3]/sum_2017,init_data[7][3]/sum_2017]

labels='male','female'
colors='yellowgreen','gold'
explode=0,0.1

fig = plt.figure(figsize=(10, 6)) 
ax_1 = fig.add_subplot(1,4,1) 
plt.axis('equal')
ax_1.set_title('2014')
#ax_1.set(title='2014')
plt.pie(mfrate_2014,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True,startangle=30)

ax_2 = fig.add_subplot(1,4,2) 
plt.axis('equal')
ax_2.set(title='2015')
plt.pie(mfrate_2015,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True,startangle=30)

ax_3 = fig.add_subplot(1,4,3) 
plt.axis('equal')
ax_3.set(title='2016')
plt.pie(mfrate_2016,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True,startangle=30)

ax_4 = fig.add_subplot(1,4,4) 
plt.axis('equal')
ax_4.set(title='2017')
plt.pie(mfrate_2017,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True,startangle=30)

plt.show()

# %%
"""
--ver 0.3/简化代码
--（应届）在籍性别人数/性别比例/各年级(2014级以后)
select xbm,njdm_id,count(*) from JW_XJGL_XSJBXXB where xjztdm='01' and njdm_id>='2014' group by xbm,njdm_id order by njdm_id,xbm
   	XBM	NJDM_ID	COUNT(*)
"""
import matplotlib.pyplot as plt

init_data=((1,1,2014,2204),
           (2,2,2014,1936),
           (3,1,2015,2079),
           (4,2,2015,2158),
           (5,1,2016,2456),
           (6,2,2016,2772),
           (7,1,2017,2740),
           (8,2,2017,2824))

num=4
mf_rate,grade=[],[]
order=range(num)

labels='male','female'
colors='yellowgreen','gold'
explode=0,0.1
fig = plt.figure(figsize=(10, 6))

for i in order:
    sum=init_data[i*2][3]+init_data[i*2+1][3]   #2014~2017
    grade.append(init_data[i*2][2])
    mf_rate.append([init_data[i*2][3]/sum,init_data[i*2+1][3]/sum])

    ax= fig.add_subplot(1,4,i+1)
    plt.axis('equal')
    ax.set_title(grade[i])
    ax.pie(mf_rate[i],explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True,startangle=30)  

plt.show()

# %%
"""
--ver 0.4/简化代码
--（应届）在籍性别人数/性别比例/各年级(2014级以后)
select xbm,njdm_id,count(*) from JW_XJGL_XSJBXXB where xjztdm='01' and njdm_id>='2014' group by xbm,njdm_id order by njdm_id,xbm
   	XBM	NJDM_ID	COUNT(*)
使用叠加柱状图表示
"""
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签

init_data=((1,1,2014,2204),
           (2,2,2014,1936),
           (3,1,2015,2079),
           (4,2,2015,2158),
           (5,1,2016,2456),
           (6,2,2016,2772),
           (7,1,2017,2740),
           (8,2,2017,2824))

num=4
ind=range(num)
m_rate,f_rate,grade=[],[],[]
fig = plt.figure(figsize=(10, 6))

for i in order:
    sum=init_data[i*2][3]+init_data[i*2+1][3]   #2014~2017
    grade.append(init_data[i*2][2])
    m_rate.append(round(init_data[i*2][3]/sum*100))
    f_rate.append(round(init_data[i*2+1][3]/sum*100))

width = 0.7       # the width of the bars: can also be len(x) sequence
p1 = plt.bar(ind, m_rate, width)
p2 = plt.bar(ind, f_rate, width,bottom=m_rate)   #叠加
plt.plot([-0.8,3.8],[50,50],'r-.')

plt.xlabel('年级')
plt.ylabel('男女比例')
plt.xticks(ind,grade)
plt.legend((p1[0],p2[0]), ('男生', '女生'))

plt.show()

# %%
"""
--ver 0.41/简化代码
--（应届）在籍性别人数/性别比例/各年级(2014级以后)
select jg_id,xbm,count(*) from JW_XJGL_XSJBXXB where xjztdm='01' and njdm_id>='2014' group by jg_id,xbm order by jg_id,xbm
使用叠加柱状图表示
"""
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签

init_data=( (1,'01',1,162),
            (2,'01',2,1506),
            (3,'02',1,824),
            (4,'02',2,1999),
            (5,'03',1,177),
            (6,'03',2,1365),
            (7,'04',1,493),
            (8,'04',2,767),
            (9,'05',1,1254),
            (10,'05',2,449),
            (11,'06',1,449),
            (12,'06',2,679),
            (13,'07',1,1059),
            (14,'07',2,100),
            (15,'08',1,7),
            (16,'08',2,60),
            (17,'09',1,1370),
            (18,'09',2,652),
            (19,'12',1,930),
            (20,'12',2,263),
            (21,'15',1,954),
            (22,'15',2,587),
            (23,'16',1,1466),
            (24,'16',2,287),
            (25,'17',1,334),
            (26,'17',2,976)
          )
fig = plt.figure(figsize=(10, 6))
num=13
m_rate,f_rate,xy=[],[],[]
ind=range(num)

for i in ind:
    sum=init_data[i*2][3]+init_data[i*2+1][3]   #2014~2017
    xy.append(init_data[i*2][1])
    m_rate.append(round(init_data[i*2][3]/sum*100))
    f_rate.append(round(init_data[i*2+1][3]/sum*100))
    

width = 0.7      # the width of the bars: can also be len(x) sequence
p1 = plt.bar(ind, m_rate, width)
p2 = plt.bar(ind, f_rate, width,bottom=m_rate)   #叠加
plt.plot([-1,num+1],[50,50],'r-.')

plt.xlabel('学院')
plt.ylabel('男女比例')
plt.xticks(ind,xy)
plt.legend((p1[0],p2[0]), ('男生', '女生'))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

init_data=( (1,'01',1,162),
            (2,'01',2,1506),
            (3,'02',1,824),
            (4,'02',2,1999),
            (5,'03',1,177),
            (6,'03',2,1365),
            (7,'04',1,493),
            (8,'04',2,767),
            (9,'05',1,1254),
            (10,'05',2,449),
            (11,'06',1,449),
            (12,'06',2,679),
            (13,'07',1,1059),
            (14,'07',2,100),
            (15,'08',1,7),
            (16,'08',2,60),
            (17,'09',1,1370),
            (18,'09',2,652),
            (19,'12',1,930),
            (20,'12',2,263),
            (21,'15',1,954),
            (22,'15',2,587),
            (23,'16',1,1466),
            (24,'16',2,287),
            (25,'17',1,334),
            (26,'17',2,976)
          )

plt.figure(figsize=(8,8))
num=13
m_rate,f_rate,xy,m_sum,f_sum=[],[],[],[],[]
ind=range(num)

for i in ind:
    m_sum.append(init_data[i*2][3])
    f_sum.append(init_data[i*2+1][3])
    sum=m_sum[i]+f_sum[i]
    xy.append(init_data[i*2][1])
    m_rate.append(round(init_data[i*2][3]/sum*100))
    f_rate.append(round(init_data[i*2+1][3]/sum*100))

p1=plt.scatter(ind,m_rate, s=m_sum, c='y')
p2=plt.scatter(ind,f_rate, s=f_sum, c='b')
plt.plot([-1,num+1],[50,50],'r-.')

plt.xlabel('学院')
plt.ylabel('男女比例')
plt.xticks(ind,xy)
plt.grid(True)

plt.show()
