# %% [markdown]
# # 数据分析本地数据版本：xscjb.csv

# %%
import pandas as pd

#从本地数据文件中读取成绩数据
#xscjb_df=pd.read_csv("../data/xscjb.csv")
xscjb_df=pd.read_csv("../data/xscjb.csv",nrows=10000)
xscjb_df.head()
#print(xscjb_df)
xscjb_df
# Out:
#       Unnamed: 0   XNM  XQM SFXWKC      XNMMC  XQMMC XB  XBM  JGMC  JG_ID  \
# 0              0  2011   12      否  2011-2012      2  女    2  人文学院      1
# 1              1  2011    3      否  2011-2012      1  女    2  人文学院      1
# 2              2  2011    3      否  2011-2012      1  女    2  人文学院      1
# 3              3  2011    3      否  2011-2012      1  女    2  人文学院      1
# 4              4  2011   12      否  2011-2012      2  女    2  人文学院      1
# 5              5  2011    3      否  2011-2012      1  女    2  人文学院      1
# 6              6  2014    3      否  2014-2015      1  女    2  人文学院      1
# 7              7  2011    3      否  2011-2012      1  女    2  人文学院      1
# 8              8  2011    3      否  2011-2012      1  女    2  人文学院      1
# 9              9  2011   12      否  2011-2012      2  女    2  人文学院      1
# 10            10  2014    3      否  2014-2015      1  女    2  人文学院      1
# 11            11  2011    3      是  2011-2012      1  女    2  人文学院      1
# ...

# %%
xscjb_df.columns
xscjb_df.XNM>2011
xscjb_df.XNMMC=='2011-2012'
xscjb_01_df=xscjb_df[xscjb_df.XNMMC=='2011-2012']
xscjb_01_df
# Out:
#     Unnamed: 0   XNM  XQM SFXWKC      XNMMC  XQMMC XB  XBM  JGMC  JG_ID ...   \
# 0            0  2011   12      否  2011-2012      2  女    2  人文学院      1 ...
# 1            1  2011    3      否  2011-2012      1  女    2  人文学院      1 ...
# 2            2  2011    3      否  2011-2012      1  女    2  人文学院      1 ...
# 3            3  2011    3      否  2011-2012      1  女    2  人文学院      1 ...
# 4            4  2011   12      否  2011-2012      2  女    2  人文学院      1 ...
# 5            5  2011    3      否  2011-2012      1  女    2  人文学院      1 ...
# 7            7  2011    3      否  2011-2012      1  女    2  人文学院      1 ...
# 8            8  2011    3      否  2011-2012      1  女    2  人文学院      1 ...
# 9            9  2011   12      否  2011-2012      2  女    2  人文学院      1 ...
# 11          11  2011    3      是  2011-2012      1  女    2  人文学院      1 ...
# 12          12  2011    3      否  2011-2012      1  女    2  人文学院      1 ...
# ...
